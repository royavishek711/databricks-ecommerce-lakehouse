# %%
# df= spark.read. \
#         option("inferSchema","true"). \
#         option("header","true").\
#         csv("/Volumes/workspace/default/raw_data/orders.csv")
# display(df)

# different way of writing the same above code
df = (spark.read
      .format('csv')
      .option("inferSchema","true")
      .option("header","true")
      .load("/Volumes/workspace/default/raw_data/orders.csv"))

df.printSchema()

# %%
# Same above thing we can write in parquet format
df.write.mode("overwrite").parquet("/Volumes/workspace/default/raw_data/orders")
